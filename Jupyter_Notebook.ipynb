# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Tools for data science

# %% [markdown]
# ###### This is a notebook for final peer assignment.

# %% [markdown]
# ###### There are many data science languages. A few of them being Python, R, SQL, Scala, Java, Julia, C++, JavaScript, Ruby, SAS, Apache Spark.

# %% [markdown]
# ###### A few of the libraries are Pandas, TensorFlow, Matplotlib, NumPy, Scikit-learn, SciPy, PyTorch, Keras

# %% [markdown]
# | Tool 1 | Tool 2 | Tool 3 | Tool 4 | Tool 5 | Tool 6 | Tool 7 | Tool 8 |
# |-------- | ------ | ----- | ------ | ------ | ------ | ------ | ------ |
# | Apache Spark | KNIME | Jupyter | TensorFlow | Tableau | MATLAB | Python | Hadoop |

# %% [markdown]
# Introduction to arithmetic expressions $1+2=3$

# %%
a=10
b=4
result = a+b
print(result)
# Out:
# 14

# %%
num1=2
num2=3
result = num1*num2
print(result)
# Out:
# 6

# %%
minutes = 120
hours = minutes/60
print(minutes, "minutes in hours: {:.2f} hours".format(hours))
# Out:
# 120 minutes in hours: 2.00 hours

# %% [markdown]
# ### Some of the objectives are:
# ###### Learn the differnt tools available for data science
# ###### Improve knowledge of why data science is important

# %% [markdown]
# ###### My name is SS
